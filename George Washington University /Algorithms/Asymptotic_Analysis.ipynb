# %% [markdown]
# # Project 1: Asymptotic  Analysis – Time Complexity
#
# ### Sri Sankeerth Koduru - G42612138

# %% [markdown]
# Create a program to include and run the code for different values of n.  (You will have to play with
# different values of n that make sense for your question.)
#
#         a. Document time taken for different values of n

# %%
# Import functions
import math
import time
import random
import numpy as np
import pandas as pd

# %%
# Setting Values of n
n_values = []
for n in range(5):
    n_values.append(50**(n+1))

# %%
def algorithm(n):
    Sum = 0
    j = 5
    while j < math.log(n):
        k = 5
        while k < n:
            Sum += a[math.floor(j)] * b[math.floor(k)]
            k = k**1.5
        j = 1.2*j

# %%
# Calculating the time complexity
time_taken = []
for n in n_values:
    a = np.array(np.random.randint(low = 1,high=100,size=n))
    b = np.array(np.random.randint(low = 1,high=100,size=n))
    start_time = time.time()
    algorithm(n)
    end_time = time.time()
    time_taken.append(end_time-start_time)

# %%
# Creating a dictionary with the data
dictionary = {"n":n_values , "Time_taken_in_seconds": time_taken}
df = pd.DataFrame(dictionary,columns=["n","Time_taken_in_seconds"])
df
# Out:
#            n  Time_taken_in_seconds
# 0         50               0.000010
# 1       2500               0.000032
# 2     125000               0.000069
# 3    6250000               0.000083
# 4  312500000               0.000107

# %%
# Creating DataFrame
df = pd.DataFrame(dictionary,columns=["n","Time_taken_in_seconds"])
df
# Out:
#            n  Time_taken_in_seconds
# 0         50               0.000010
# 1       2500               0.000032
# 2     125000               0.000069
# 3    6250000               0.000083
# 4  312500000               0.000107

# %%
# Exporting the DataFrame
df.to_csv('Asymptotic_Analysis.csv')
